# %%
import pandas as pd

# %%
# 2 main datatypes
series = pd.Series(["BMW", "Toyota", "Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# series is 1-dimensional

# %%
colours = pd.Series(["Red","Blue", "White"])
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
# DataFrame = 2-dimensinal

# %%
car_data = pd.DataFrame({"Car make" : series, "Colour": colours})
car_data
# Out:
#   Car make Colour
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  White

# %%
# Import Data
car_sales = pd.read_csv("51 - car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Exporting a dataframe
car_sales.to_csv("exported-car-sales.csv", index= False)

# %%
exported_car_sales = pd.read_csv("exported-car-sales.csv")
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe data

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_prices = pd.Series([3000,1500,111250,])
car_prices.mean()
# Out:
# 38583.333333333336

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# ## Viewing and selecting data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .loc and .iloc
animals = pd.Series(["cat", "dog", "bird", "pandas", "snake"],
                   index = [0,3,9,8,3])

animals
# Out:
# 0       cat
# 3       dog
# 9      bird
# 8    pandas
# 3     snake
# dtype: object

# %%
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals.iloc[3]
# Out:
# 'pandas'

# %%
animals
# Out:
# 0       cat
# 3       dog
# 9      bird
# 8    pandas
# 3     snake
# dtype: object

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# groupby
car_sales.groupby(["Make"]).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales["Odometer (KM)"].plot()

# %%
car_sales["Odometer (KM)"].hist()

# %%
car_sales["Price"].dtype

# %%
car_sales["Price"] = car_sales["Price"].str.replace(r'[\$,\.]', '', regex=True).astype(int)

# %%
  car_sales["Price"].plot()

# %% [markdown]
# ## Manipulating Data

# %%
car_sales["Make"].str.lower()

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales

# %%
car_sales_missing = pd.read_csv("58 - car-sales-missing-data.csv")
car_sales_missing

# %%
car_sales_missing["Odometer"] = car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())

# %%
car_sales_missing

# %%
car_sales_missing.dropna()

# %%
car_sales_missing.dropna(inplace = True)

# %%
car_sales_missing
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 car_sales_missing
#
# NameError: name 'car_sales_missing' is not defined

# %%
car_sales_missing = pd.read_csv("58 - car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv("car-sales-missing-dropped.csv")

# %%
import pandas as pd
# Column from series
seats_column = pd.Series([5,5,5,5,5])

# New columns added called seats
car_sales["Seats"] = seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# 5  Toyota  Green          99213      4   $4,500.00    NaN
# 6   Honda   Blue          45698      4   $7,500.00    NaN
# 7   Honda   Blue          54738      4   $7,000.00    NaN
# 8  Toyota  White          60000      4   $6,250.00    NaN
# 9  Nissan  White          31600      4   $9,700.00    NaN

# %%
car_sales["Seats"].fillna(5, inplace = True)
# Out:
# C:\Users\MR.CRIMINAL\AppData\Local\Temp\ipykernel_57352\2627188857.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales["Seats"].fillna(5, inplace = True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0
# 6   Honda   Blue          45698      4   $7,500.00    5.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0
# 8  Toyota  White          60000      4   $6,250.00    5.0
# 9  Nissan  White          31600      4   $9,700.00    5.0

# %%
# Column from the python list 
fuel_economy = [7.5, 9.2, 5.0, 9.6, 8.67, 4.7, 4.9,6.4,4.0,4.56]
car_sales["Fuel per 100 KM"]= fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100 KM
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.50
# 1   Honda    Red          87899      4   $5,000.00    5.0             9.20
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             5.00
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.60
# 4  Nissan  White         213095      4   $3,500.00    5.0             8.67
# 5  Toyota  Green          99213      4   $4,500.00    5.0             4.70
# 6   Honda   Blue          45698      4   $7,500.00    5.0             4.90
# 7   Honda   Blue          54738      4   $7,000.00    5.0             6.40
# 8  Toyota  White          60000      4   $6,250.00    5.0             4.00
# 9  Nissan  White          31600      4   $9,700.00    5.0             4.56

# %%
# Column from another columns
car_sales["Total fuel used (L)"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100 KM"] 
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100 KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.50
# 1   Honda    Red          87899      4   $5,000.00    5.0             9.20
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             5.00
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.60
# 4  Nissan  White         213095      4   $3,500.00    5.0             8.67
# 5  Toyota  Green          99213      4   $4,500.00    5.0             4.70
# 6   Honda   Blue          45698      4   $7,500.00    5.0             4.90
# 7   Honda   Blue          54738      4   $7,000.00    5.0             6.40
# 8  Toyota  White          60000      4   $6,250.00    5.0             4.00
# 9  Nissan  White          31600      4   $9,700.00    5.0             4.56
#
#    Total fuel used  Total fuel used (L)
# 0       11253.2250           11253.2250
# 1        8086.7080            8086.7080
# ...

# %%
# Create a column from a single values
car_sales["Number of wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100 KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.50
# 1   Honda    Red          87899      4   $5,000.00    5.0             9.20
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             5.00
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.60
# 4  Nissan  White         213095      4   $3,500.00    5.0             8.67
# 5  Toyota  Green          99213      4   $4,500.00    5.0             4.70
# 6   Honda   Blue          45698      4   $7,500.00    5.0             4.90
# 7   Honda   Blue          54738      4   $7,000.00    5.0             6.40
# 8  Toyota  White          60000      4   $6,250.00    5.0             4.00
# 9  Nissan  White          31600      4   $9,700.00    5.0             4.56
#
#    Total fuel used  Total fuel used (L)  Number of wheels
# 0       11253.2250           11253.2250                 4
# ...

# %%
car_sales["Passed road safty"] = True
car_sales.dtypes
# Out:
# Make                    object
# Colour                  object
# Odometer (KM)            int64
# Doors                    int64
# Price                   object
# Seats                  float64
# Fuel per 100 KM        float64
# Total fuel used        float64
# Total fuel used (L)    float64
# Number of wheels         int64
# Passed road safty         bool
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100 KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.50
# 1   Honda    Red          87899      4   $5,000.00    5.0             9.20
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             5.00
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.60
# 4  Nissan  White         213095      4   $3,500.00    5.0             8.67
# 5  Toyota  Green          99213      4   $4,500.00    5.0             4.70
# 6   Honda   Blue          45698      4   $7,500.00    5.0             4.90
# 7   Honda   Blue          54738      4   $7,000.00    5.0             6.40
# 8  Toyota  White          60000      4   $6,250.00    5.0             4.00
# 9  Nissan  White          31600      4   $9,700.00    5.0             4.56
#
#    Total fuel used  Total fuel used (L)  Number of wheels  Passed road safty
# ...

# %%
car_sales = car_sales.drop("Total fuel used", axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 car_sales = car_sales.drop("Total fuel used", axis = 1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100 KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.50
# 1   Honda    Red          87899      4   $5,000.00    5.0             9.20
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             5.00
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.60
# 4  Nissan  White         213095      4   $3,500.00    5.0             8.67
# 5  Toyota  Green          99213      4   $4,500.00    5.0             4.70
# 6   Honda   Blue          45698      4   $7,500.00    5.0             4.90
# 7   Honda   Blue          54738      4   $7,000.00    5.0             6.40
# 8  Toyota  White          60000      4   $6,250.00    5.0             4.00
# 9  Nissan  White          31600      4   $9,700.00    5.0             4.56
#
#    Total fuel used (L)  Number of wheels  Passed road safty
# 0           11253.2250                 4               True
# ...

# %%
car_sales_shuffled = car_sales.sample(frac = 1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100 KM  \
# 1   Honda    Red          87899      4   $5,000.00    5.0             9.20
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.50
# 5  Toyota  Green          99213      4   $4,500.00    5.0             4.70
# 7   Honda   Blue          54738      4   $7,000.00    5.0             6.40
# 6   Honda   Blue          45698      4   $7,500.00    5.0             4.90
# 4  Nissan  White         213095      4   $3,500.00    5.0             8.67
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             5.00
# 9  Nissan  White          31600      4   $9,700.00    5.0             4.56
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.60
# 8  Toyota  White          60000      4   $6,250.00    5.0             4.00
#
#    Total fuel used (L)  Number of wheels  Passed road safty
# 1            8086.7080                 4               True
# ...

# %%
# only select 20% of data 
car_sales_shuffled.sample(frac = 0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Seats  Fuel per 100 KM  \
# 0  Toyota  White         150043      4  $4,000.00    5.0             7.50
# 4  Nissan  White         213095      4  $3,500.00    5.0             8.67
#
#    Total fuel used (L)  Number of wheels  Passed road safty
# 0           11253.2250                 4               True
# 4           18475.3365                 4               True

# %%
car_sales_shuffled.reset_index(drop = True , inplace = True)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100 KM  \
# 0   Honda    Red          87899      4   $5,000.00    5.0             9.20
# 1  Toyota  White         150043      4   $4,000.00    5.0             7.50
# 2  Toyota  Green          99213      4   $4,500.00    5.0             4.70
# 3   Honda   Blue          54738      4   $7,000.00    5.0             6.40
# 4   Honda   Blue          45698      4   $7,500.00    5.0             4.90
# 5  Nissan  White         213095      4   $3,500.00    5.0             8.67
# 6  Toyota   Blue          32549      3   $7,000.00    5.0             5.00
# 7  Nissan  White          31600      4   $9,700.00    5.0             4.56
# 8     BMW  Black          11179      5  $22,000.00    5.0             9.60
# 9  Toyota  White          60000      4   $6,250.00    5.0             4.00
#
#    Total fuel used (L)  Number of wheels  Passed road safty
# 0            8086.7080                 4               True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100 KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.50
# 1   Honda    Red          87899      4   $5,000.00    5.0             9.20
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             5.00
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.60
# 4  Nissan  White         213095      4   $3,500.00    5.0             8.67
# 5  Toyota  Green          99213      4   $4,500.00    5.0             4.70
# 6   Honda   Blue          45698      4   $7,500.00    5.0             4.90
# 7   Honda   Blue          54738      4   $7,000.00    5.0             6.40
# 8  Toyota  White          60000      4   $6,250.00    5.0             4.00
# 9  Nissan  White          31600      4   $9,700.00    5.0             4.56
#
#    Total fuel used (L)  Number of wheels  Passed road safty
# 0           11253.2250                 4               True
# ...

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x:x/1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100 KM  \
# 0  Toyota  White      93776.875      4   $4,000.00    5.0             7.50
# 1   Honda    Red      54936.875      4   $5,000.00    5.0             9.20
# 2  Toyota   Blue      20343.125      3   $7,000.00    5.0             5.00
# 3     BMW  Black       6986.875      5  $22,000.00    5.0             9.60
# 4  Nissan  White     133184.375      4   $3,500.00    5.0             8.67
# 5  Toyota  Green      62008.125      4   $4,500.00    5.0             4.70
# 6   Honda   Blue      28561.250      4   $7,500.00    5.0             4.90
# 7   Honda   Blue      34211.250      4   $7,000.00    5.0             6.40
# 8  Toyota  White      37500.000      4   $6,250.00    5.0             4.00
# 9  Nissan  White      19750.000      4   $9,700.00    5.0             4.56
#
#    Total fuel used (L)  Number of wheels  Passed road safty
# 0           11253.2250                 4               True
# ...
